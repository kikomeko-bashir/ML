# %% [markdown]
# Exploring the bagging algorithm

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import GridSearchCV

RandomForestClassifier().get_params()
# Out:
# {'bootstrap': True,
#  'ccp_alpha': 0.0,
#  'class_weight': None,
#  'criterion': 'gini',
#  'max_depth': None,
#  'max_features': 'sqrt',
#  'max_leaf_nodes': None,
#  'max_samples': None,
#  'min_impurity_decrease': 0.0,
#  'min_samples_leaf': 1,
#  'min_samples_split': 2,
#  'min_weight_fraction_leaf': 0.0,
#  'monotonic_cst': None,
#  'n_estimators': 100,
#  'n_jobs': None,
#  'oob_score': False,
#  'random_state': None,
#  'verbose': 0,
#  'warm_start': False}

# %%
import joblib
import pandas as pd
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import GridSearchCV


tr_features = pd.read_csv('train_features.csv')
tr_labels = pd.read_csv('train_labels.csv')

# %% [markdown]
# Hyperparameter tuning

# %%
def print_results(results):
    print('BEST PARAMS: {}\n'.format(results.best_params_))

    means = results.cv_results_['mean_test_score']
    stds = results.cv_results_['std_test_score']
    for mean, std, params in zip(means, stds, results.cv_results_['params']):
        print('{} (+/-{}) for {}'.format(round(mean, 3), round(std * 2, 3), params))

# %%
rf = RandomForestClassifier()
parameters= {
    'n_estimators': [5, 50, 250, 500],
    'max_depth': [4, 8, 16, 32, None]
}

cv = GridSearchCV(rf, parameters, cv=5)
cv.fit(tr_features, tr_labels.values.ravel())

print_results(cv)
# Out:
# BEST PARAMS: {'max_depth': 8, 'n_estimators': 500}
#
# 0.815 (+/-0.109) for {'max_depth': 4, 'n_estimators': 5}
# 0.82 (+/-0.11) for {'max_depth': 4, 'n_estimators': 50}
# 0.817 (+/-0.111) for {'max_depth': 4, 'n_estimators': 250}
# 0.82 (+/-0.105) for {'max_depth': 4, 'n_estimators': 500}
# 0.79 (+/-0.089) for {'max_depth': 8, 'n_estimators': 5}
# 0.818 (+/-0.104) for {'max_depth': 8, 'n_estimators': 50}
# 0.815 (+/-0.085) for {'max_depth': 8, 'n_estimators': 250}
# 0.822 (+/-0.078) for {'max_depth': 8, 'n_estimators': 500}
# 0.787 (+/-0.069) for {'max_depth': 16, 'n_estimators': 5}
# 0.809 (+/-0.067) for {'max_depth': 16, 'n_estimators': 50}
# 0.807 (+/-0.083) for {'max_depth': 16, 'n_estimators': 250}
# 0.817 (+/-0.07) for {'max_depth': 16, 'n_estimators': 500}
# 0.783 (+/-0.054) for {'max_depth': 32, 'n_estimators': 5}
# 0.807 (+/-0.095) for {'max_depth': 32, 'n_estimators': 50}
# 0.811 (+/-0.073) for {'max_depth': 32, 'n_estimators': 250}
# 0.803 (+/-0.087) for {'max_depth': 32, 'n_estimators': 500}
# 0.787 (+/-0.075) for {'max_depth': None, 'n_estimators': 5}
# 0.818 (+/-0.08) for {'max_depth': None, 'n_estimators': 50}
# 0.803 (+/-0.064) for {'max_depth': None, 'n_estimators': 250}
# 0.805 (+/-0.072) for {'max_depth': None, 'n_estimators': 500}

# %%
cv.best_estimator_
# Out:
# RandomForestClassifier(max_depth=8, n_estimators=500)

# %%
joblib.dump(cv.best_estimator_, 'models/RF_model.pk1')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[26], line 1
# ----> 1 joblib.dump(cv.best_estimator_, 'models/RF_model.pk1')
#
# File C:\ProgramData\anaconda3\Lib\site-packages\joblib\numpy_pickle.py:552, in dump(value, filename, compress, protocol, cache_size)
#     550         NumpyPickler(f, protocol=protocol).dump(value)
#     551 elif is_filename:
# --> 552     with open(filename, 'wb') as f:
#     553         NumpyPickler(f, protocol=protocol).dump(value)
#     554 else:
#
# FileNotFoundError: [Errno 2] No such file or directory: 'models/RF_model.pk1'
